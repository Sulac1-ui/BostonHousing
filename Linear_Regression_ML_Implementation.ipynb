# %% [markdown]
# ##Importing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Lets load the Boston House Pricing Dataset

# %%
boston = pd.read_csv("boston_data_final.csv")

# %%
boston
# Out:
#       uf     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0      0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1      1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2      2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3      3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4      4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..   ...      ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  Price
# ...

# %%
#gives only the 1st row name 
boston.keys()
# Out:
# Index(['uf', 'CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT', 'Price'],
#       dtype='object')

# %%
print(boston)
# Out:
#       uf     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0      0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1      1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2      2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3      3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4      4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..   ...      ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  Price
# ...

# %%
boston.head()
# Out:
#    uf     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0   0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1   1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2   2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3   3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4   4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  Price
# 0     15.3  396.90   4.98   24.0
# 1     17.8  396.90   9.14   21.6
# 2     17.8  392.83   4.03   34.7
# 3     18.7  394.63   2.94   33.4
# 4     18.7  396.90   5.33   36.2

# %%
print(boston.feature_names)
# Out:
# ['CRIM' 'ZN' 'INDUS' 'CHAS' 'NOX' 'RM' 'AGE' 'DIS' 'RAD' 'TAX' 'PTRATIO'
#  'B' 'LSTAT']

# %% [markdown]
# ## Preparing The Dataset

# %%
dataset = pd.DataFrame(boston.data,columns=boston.feature_names)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 dataset = pd.DataFrame(boston.data,columns=boston.feature_names)
#
# File c:\Users\Aadim\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'data'

# %%
boston.head()
# Out:
#    uf     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0   0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1   1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2   2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3   3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4   4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  Price
# 0     15.3  396.90   4.98   24.0
# 1     17.8  396.90   9.14   21.6
# 2     17.8  392.83   4.03   34.7
# 3     18.7  394.63   2.94   33.4
# 4     18.7  396.90   5.33   36.2

# %%
dataset['Price']=boston.target

# %%
boston.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 15 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   uf       506 non-null    int64
#  1   CRIM     506 non-null    float64
#  2   ZN       506 non-null    float64
#  3   INDUS    506 non-null    float64
#  4   CHAS     506 non-null    float64
#  5   NOX      506 non-null    float64
#  6   RM       506 non-null    float64
#  7   AGE      506 non-null    float64
#  8   DIS      506 non-null    float64
#  9   RAD      506 non-null    float64
#  10  TAX      506 non-null    float64
#  11  PTRATIO  506 non-null    float64
#  12  B        506 non-null    float64
#  13  LSTAT    506 non-null    float64
#  14  Price    506 non-null    float64
# dtypes: float64(14), int64(1)
# memory usage: 59.4 KB

# %%
## Summarizing The Stats of the data
boston.describe()
# Out:
#                uf        CRIM          ZN       INDUS        CHAS         NOX  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean   252.500000    3.613524   11.363636   11.136779    0.069170    0.554695
# std    146.213884    8.601545   23.322453    6.860353    0.253994    0.115878
# min      0.000000    0.006320    0.000000    0.460000    0.000000    0.385000
# 25%    126.250000    0.082045    0.000000    5.190000    0.000000    0.449000
# 50%    252.500000    0.256510    0.000000    9.690000    0.000000    0.538000
# 75%    378.750000    3.677083   12.500000   18.100000    0.000000    0.624000
# max    505.000000   88.976200  100.000000   27.740000    1.000000    0.871000
#
#                RM         AGE         DIS         RAD         TAX     PTRATIO  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     6.284634   68.574901    3.795043    9.549407  408.237154   18.455534
# ...

# %%
## Check the missing Values
boston.isnull().sum()
# Out:
# uf         0
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# Price      0
# dtype: int64

# %%
### EXploratory Data Analysis
## Correlation
boston.corr()
# Out:
#                uf      CRIM        ZN     INDUS      CHAS       NOX        RM  \
# uf       1.000000  0.407407 -0.103393  0.399439 -0.003759  0.398736 -0.079971
# CRIM     0.407407  1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247
# ZN      -0.103393 -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991
# INDUS    0.399439  0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676
# CHAS    -0.003759 -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251
# NOX      0.398736  0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188
# RM      -0.079971 -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000
# AGE      0.203784  0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265
# DIS     -0.302211 -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246
# RAD      0.686002  0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847
# TAX      0.666626  0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048
# ...

# %%
#Nothing but just creating a graph 
import seaborn as sns
sns.pairplot(boston)

# %% [markdown]
# ## Analyzing The Correlated Features

# %%
boston.corr()
# Out:
#                uf      CRIM        ZN     INDUS      CHAS       NOX        RM  \
# uf       1.000000  0.407407 -0.103393  0.399439 -0.003759  0.398736 -0.079971
# CRIM     0.407407  1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247
# ZN      -0.103393 -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991
# INDUS    0.399439  0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676
# CHAS    -0.003759 -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251
# NOX      0.398736  0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188
# RM      -0.079971 -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000
# AGE      0.203784  0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265
# DIS     -0.302211 -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246
# RAD      0.686002  0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847
# TAX      0.666626  0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048
# ...

# %%
#Plotting graph between crime rate and price of Boston
plt.scatter(boston['CRIM'],boston['Price'])
plt.xlabel("Crime Rate")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
plt.scatter(boston['RM'],boston['Price'])
plt.xlabel("RM")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
import seaborn as sns
sns.regplot(x="RM",y="Price",data=boston)
# Out:
# <AxesSubplot: xlabel='RM', ylabel='Price'>

# %%
sns.regplot(x="LSTAT",y="Price",data=dataset)

# %%
sns.regplot(x="CHAS",y="Price",data=dataset)
# Out:
# <AxesSubplot:xlabel='CHAS', ylabel='Price'>

# %%
sns.regplot(x="PTRATIO",y="Price",data=dataset)

# %%
## Independent and Dependent features
#remove last coloumn from the boston dataset, since[:it denotes row,:it denotes coloumn]
x=boston.iloc[:,:-1]
y=boston.iloc[:,:-1]

# %%
boston
# Out:
#       uf     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0      0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1      1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2      2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3      3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4      4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..   ...      ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  Price
# ...

# %%
x.head()
# Out:
#    uf     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0   0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1   1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2   2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3   3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4   4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
y.head()
# Out:
#    uf     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0   0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1   1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2   2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3   3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4   4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
##Train Test Split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=50)

# %%
X_train
# Out:
#       uf      CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD  \
# 449  449   7.52601   0.0  18.10   0.0  0.713  6.417   98.3  2.1850  24.0
# 374  374  18.49820   0.0  18.10   0.0  0.668  4.138  100.0  1.1370  24.0
# 253  253   0.36894  22.0   5.86   0.0  0.431  8.259    8.4  8.9067   7.0
# 402  402   9.59571   0.0  18.10   0.0  0.693  6.404  100.0  1.6390  24.0
# 417  417  25.94060   0.0  18.10   0.0  0.679  5.304   89.1  1.6475  24.0
# ..   ...       ...   ...    ...   ...    ...    ...    ...     ...   ...
# 289  289   0.04297  52.5   5.32   0.0  0.405  6.565   22.9  7.3172   6.0
# 109  109   0.26363   0.0   8.56   0.0  0.520  6.229   91.2  2.5451   5.0
# 395  395   8.71675   0.0  18.10   0.0  0.693  6.471   98.8  1.7257  24.0
# 480  480   5.82401   0.0  18.10   0.0  0.532  6.242   64.7  3.4242  24.0
# 176  176   0.07022   0.0   4.05   0.0  0.510  6.020   47.2  3.5549   5.0
#
#        TAX  PTRATIO       B  LSTAT
# 449  666.0     20.2  304.21  19.31
# ...

# %%
X_test
# Out:
#       uf     CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD  \
# 365  365  4.55587   0.0  18.10   0.0  0.718  3.561   87.9  1.6132  24.0
# 313  313  0.26938   0.0   9.90   0.0  0.544  6.266   82.8  3.2628   4.0
# 461  461  3.69311   0.0  18.10   0.0  0.713  6.376   88.4  2.5671  24.0
# 158  158  1.34284   0.0  19.58   0.0  0.605  6.066  100.0  1.7573   5.0
# 333  333  0.05083   0.0   5.19   0.0  0.515  6.316   38.1  6.4584   5.0
# ..   ...      ...   ...    ...   ...    ...    ...    ...     ...   ...
# 304  304  0.05515  33.0   2.18   0.0  0.472  7.236   41.1  4.0220   7.0
# 421  421  7.02259   0.0  18.10   0.0  0.718  6.006   95.3  1.8746  24.0
# 497  497  0.26838   0.0   9.69   0.0  0.585  5.794   70.6  2.8927   6.0
# 65    65  0.03584  80.0   3.37   0.0  0.398  6.290   17.8  6.6115   4.0
# 87    87  0.07151   0.0   4.49   0.0  0.449  6.121   56.8  3.7476   3.0
#
#        TAX  PTRATIO       B  LSTAT
# 365  666.0     20.2  354.70   7.12
# ...

# %%
## Standardize the dataset--for the the ease of comparision we do standarzation
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
X_train=scaler.fit_transform(X_train)

# %%
X_test=scaler.transform(X_test)

# %%
import pickle
pickle.dump(scaler,open('scaling.pkl','wb'))

# %%
X_train
# Out:
# array([[ 1.32429301,  0.40963373, -0.50774405, ...,  0.79828997,
#         -0.56186146,  0.91372831],
#        [ 0.81376362,  1.60740115, -0.50774405, ...,  0.79828997,
#          0.43565995,  3.47692907],
#        [-0.00989045, -0.37166019,  0.40476816, ...,  0.29040155,
#          0.43565995, -1.25249226],
#        ...,
#        [ 0.95671185,  0.53961959, -0.50774405, ...,  0.79828997,
#          0.38271136,  0.6129025 ],
#        [ 1.53531183,  0.22383671, -0.50774405, ...,  0.79828997,
#          0.43565995, -0.26347589],
#        [-0.53403396, -0.40426964, -0.50774405, ..., -0.86389032,
#          0.39616375, -0.35001482]])

# %%
X_test
# Out:
# array([[ 0.7525001 ,  0.08540156, -0.50774405, ...,  0.79828997,
#         -0.01849264, -0.76073134],
#        [ 0.39853306, -0.38252855, -0.50774405, ..., -0.03280018,
#          0.39788565, -0.6535879 ],
#        [ 1.40597771, -0.00878071, -0.50774405, ...,  0.79828997,
#          0.37679231,  0.27361494],
#        ...,
#        [ 1.65103182, -0.38263771, -0.50774405, ...,  0.33657322,
#          0.43565995,  0.19806508],
#        [-1.28961745, -0.4080227 ,  2.81048216, ..., -1.0947487 ,
#          0.43565995, -1.09727164],
#        [-1.13986216, -0.40412882, -0.50774405, ...,  0.0133715 ,
#          0.41682661, -0.57941168]])

# %% [markdown]
# ## Model Training

# %%
from sklearn.linear_model import LinearRegression

# %%
regres=LinearRegression()

# %%
regres.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
## print the coefficients and the intercept
print(regres.coef_)
# Out:
# [[ 1.46906333e+02 -1.19422299e-13  1.35929522e-13 -2.53669773e-13
#    1.72940547e-14 -2.41235958e-13  8.36528786e-14 -2.70705210e-13
#    2.05367289e-13 -1.66059926e-13 -1.86898180e-13 -1.15763962e-13
#    1.31744289e-13 -2.24362958e-13]
#  [-6.20774335e-17  9.16053466e+00  3.10862447e-15 -4.88498131e-15
#   -2.70616862e-15 -1.06581410e-14  7.71605002e-15 -9.10382880e-15
#    3.55271368e-15 -7.10542736e-15 -9.76996262e-15 -5.10702591e-15
#    6.66133815e-15 -1.15463195e-14]
#  [-2.35543973e-14 -2.08721929e-14  2.41092665e+01 -2.35367281e-14
#   -2.06085149e-15 -3.49720253e-14  2.17603713e-14 -3.03090886e-14
#    3.53050922e-14 -1.80966353e-14 -2.44249065e-14 -1.69864123e-14
#    1.81521465e-14 -3.28070904e-14]
#  [ 3.37190572e-15  8.88178420e-16 -2.22044605e-16  6.91435267e+00
#   -1.53349555e-15  2.05391260e-15 -9.15933995e-16  3.83026943e-15
#   -2.55351296e-15  4.77395901e-15 -1.33226763e-15  1.83186799e-15
#    2.77555756e-16  4.21884749e-15]
# ...

# %%
print(regres.intercept_)
# Out:
# [2.54452970e+02 3.77354604e+00 1.22413366e+01 1.10230941e+01
#  5.94059406e-02 5.52766832e-01 6.30808663e+00 6.79225248e+01
#  3.83547525e+00 9.56683168e+00 4.08155941e+02 1.84710396e+01
#  3.56418342e+02 1.26580941e+01]

# %%
## on which parameters the model has been trained
regres.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %%
### Prediction With Test Data
reg_pred=regres.predict(X_test)

# %%
reg_pred
# Out:
# array([[ 3.65000000e+02,  4.55587000e+00, -3.01980663e-13, ...,
#          2.02000000e+01,  3.54700000e+02,  7.12000000e+00],
#        [ 3.13000000e+02,  2.69380000e-01,  2.30926389e-14, ...,
#          1.84000000e+01,  3.93390000e+02,  7.90000000e+00],
#        [ 4.61000000e+02,  3.69311000e+00, -2.38031816e-13, ...,
#          2.02000000e+01,  3.91430000e+02,  1.46500000e+01],
#        ...,
#        [ 4.97000000e+02,  2.68380000e-01, -7.46069873e-14, ...,
#          1.92000000e+01,  3.96900000e+02,  1.41000000e+01],
#        [ 6.50000000e+01,  3.58400000e-02,  8.00000000e+01, ...,
#          1.61000000e+01,  3.96900000e+02,  4.67000000e+00],
#        [ 8.70000000e+01,  7.15100000e-02,  1.50990331e-13, ...,
#          1.85000000e+01,  3.95150000e+02,  8.44000000e+00]])

# %% [markdown]
# ## Assumptions/Validation

# %%
## plot a scatter plot for the prediction
import seaborn as sns 
sns.regplot(y_test,reg_pred)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[132], line 3
#       1 ## plot a scatter plot for the prediction
#       2 import seaborn as sns
# ----> 3 sns.regplot(y_test,reg_pred)
#
# TypeError: regplot() takes from 0 to 1 positional arguments but 2 were given

# %%
## Residuals
residuals=y_test-reg_pred

# %%
residuals
# Out:
#                uf          CRIM            ZN         INDUS          CHAS  \
# 365  1.989520e-12  8.437695e-14  3.019807e-13 -2.131628e-14 -1.477984e-15
# 313 -1.705303e-13 -2.081668e-14 -2.309264e-14  1.776357e-15  2.914335e-16
# 461  1.818989e-12  5.995204e-14  2.380318e-13 -2.486900e-14 -1.165734e-15
# 158  4.263256e-13  1.998401e-15  3.907985e-14  0.000000e+00 -4.163336e-17
# 333 -1.136868e-12 -5.011269e-14 -1.545430e-13  1.509903e-14  7.355228e-16
# ..            ...           ...           ...           ...           ...
# 304 -1.477929e-12 -6.642603e-14 -1.847411e-13  1.643130e-14  1.165734e-15
# 421  2.160050e-12  7.904788e-14  2.895462e-13 -2.842171e-14 -1.498801e-15
# 497  3.410605e-13  3.053113e-15  7.460699e-14 -7.105427e-15 -2.220446e-16
# 65  -2.557954e-12 -8.602841e-14 -3.552714e-13  3.197442e-14  1.852685e-15
# 87  -1.193712e-12 -4.392320e-14 -1.509903e-13  1.687539e-14  9.783840e-16
#
#               NOX            RM           AGE           DIS           RAD  \
# ...

# %%
## Plot this residuals 

sns.displot(residuals,kind="kde")

# %%
## Scatter plot with respect to prediction and residuals
## uniform distribution
plt.scatter(reg_pred,residuals)

# %%
sns.regplot(reg_pred, residuals)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

print(mean_absolute_error(y_test,reg_pred))
print(mean_squared_error(y_test,reg_pred))
print(np.sqrt(mean_squared_error(y_test,reg_pred)))
# Out:
# 2.2096194553883044e-13
# 2.8394695837351092e-25
# 5.3286673603586e-13

# %% [markdown]
# ## R square and adjusted R square/Model Test/ Evaluation

# %% [markdown]
# Formula
#
# **R^2 = 1 - SSR/SST**
#
#
# R^2	=	coefficient of determination
# SSR	=	sum of squares of residuals
# SST	=	total sum of squares

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,reg_pred)
print(score)
# Out:
# 0.7112260057484932

# %% [markdown]
# **Adjusted R2 = 1 – [(1-R2)*(n-1)/(n-k-1)]**
#
# where:
#
# R2: The R2 of the model
# n: The number of observations
# k: The number of predictor variables

# %%
#display adjusted R-squared
1 - (1-score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
# Out:
# 0.6840226584639308

# %% [markdown]
# ## New Data Prediction

# %%
boston.data[0].reshape(1,-1)
# Out:
# array([[6.320e-03, 1.800e+01, 2.310e+00, 0.000e+00, 5.380e-01, 6.575e+00,
#         6.520e+01, 4.090e+00, 1.000e+00, 2.960e+02, 1.530e+01, 3.969e+02,
#         4.980e+00]])

# %%
##transformation of new data
scaler.transform(boston.data[0].reshape(1,-1))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   "X does not have valid feature names, but"
# array([[-0.41709233,  0.29216419, -1.27338003, -0.28154625, -0.16513629,
#          0.34715902, -0.13030059,  0.15267164, -0.97798895, -0.66777595,
#         -1.32142483,  0.42854113, -1.04769976]])

# %%
regression.predict(scaler.transform(boston.data[0].reshape(1,-1)))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   "X does not have valid feature names, but"
# array([30.08649576])

# %% [markdown]
# ## Pickling The Model file For Deployment/ Model Save

# %%
import pickle

# %%
pickle.dump(regres,open('regmodel.pkl','wb'))

# %%
pickled_model=pickle.load(open('regmodel.pkl','rb'))

# %%
## Prediction
pickled_model.predict(scaler.transform(boston.data[0].reshape(1,-1)))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[145], line 2
#       1 ## Prediction
# ----> 2 pickled_model.predict(scaler.transform(boston.data[0].reshape(1,-1)))
#
# File c:\Users\Aadim\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'data'
